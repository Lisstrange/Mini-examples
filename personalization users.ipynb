# %%
import pandas as pd

# %% [markdown]
# Одной из задач персонализации на mos.ru является районная персонализация. Для того чтобы персонализировать посетителей по районам, в том числе используется история посещений посетителей на сайтах районов и управ города Москвы. Основная гипотеза для решения задачи районной персонализации: «Посетитель переходит на сайты управ и районов тогда, когда эти сайты являются его «домашними» или «рабочими», то есть когда посетитель живет или работает в этом районе». Необходимо сформулировать уточнение по этой гипотезе, сгенерить фичи, и объяснить их.

# %%
PATH='/Users/nikli/Documents/git_reps/Data/DS Jun/'
pd.read_csv(PATH + 'stream.csv')
# Out:
#                               visitor_id       visit_ts device  \
# 0       f2c7d520aa006d389fada86f03a1c3c5  1589795523698  Other
# 1       f2c7d520aa006d389fada86f03a1c3c5  1589795523736  Other
# 2       f2c7d520aa006d389fada86f03a1c3c5  1589795523776  Other
# 3       f2c7d520aa006d389fada86f03a1c3c5  1589795525795  Other
# 4       f2c7d520aa006d389fada86f03a1c3c5  1589795541837  Other
# ...                                  ...            ...    ...
# 939457  be75245322c36d0c9fddb85603a78181  1589363103677   iPad
# 939458  be75245322c36d0c9fddb85603a78181  1589363103514   iPad
# 939459  be75245322c36d0c9fddb85603a78181  1589363103297   iPad
# 939460  be75245322c36d0c9fddb85603a78181  1589363103674   iPad
# 939461  be75245322c36d0c9fddb85603a78181  1589627741187   iPad
#
#                       host
# 0              uzao.mos.ru
# 1              uzao.mos.ru
# 2              uzao.mos.ru
# 3              uzao.mos.ru
# 4              uzao.mos.ru
# ...                    ...
# ...
